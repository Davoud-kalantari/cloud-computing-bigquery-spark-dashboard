# %%
# %sql
SELECT 
  AVG(`Time on App`) AS avg_time_on_app,
  AVG(`Time on Website`) AS avg_time_on_website
FROM ecommerce_customers
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_time_on_app</th><th>avg_time_on_website</th></tr></thead><tbody><tr><td>14.350284262734618</td><td>33.95692625943925</td></tr></tbody></table></div>
