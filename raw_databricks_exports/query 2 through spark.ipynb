# %%
# Load the Delta table (created from the uploaded file) into a Spark DataFrame
df = spark.table("default.ecommerce_customers")
df.selectExpr(
    "AVG(`Time on App`) as avg_time_on_app",
    "AVG(`Time on Website`) as avg_time_on_website"
).show()
# Out:
# +------------------+-------------------+
# |   avg_time_on_app|avg_time_on_website|
# +------------------+-------------------+
# |14.350284262734618|  33.95692625943925|
# +------------------+-------------------+
