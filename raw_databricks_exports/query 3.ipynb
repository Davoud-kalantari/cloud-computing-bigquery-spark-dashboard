# %%
# %sql
SELECT 
  AVG(`Yearly Amount Spent`) AS avg_spending_long_sessions
FROM default.ecommerce_customers
WHERE `Avg. Session Length` > 34
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>avg_spending_long_sessions</th></tr></thead><tbody><tr><td>545.0664955527343</td></tr></tbody></table></div>
